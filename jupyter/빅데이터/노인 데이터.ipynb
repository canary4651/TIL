# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium
# %matplotlib inline
import os
import requests
# key = os.environ['KAKAO_REST_API_KEY']
# LOCATIONIQ_TOKEN = os.environ['LOCATIONIQ_TOKEN']

# %%
# Matplotlib 사용

import matplotlib
import matplotlib.pyplot as plt

matplotlib.__version__
# Out:
# '3.1.0'

# %%
# matplotlib에 “AppleGothc”(Mac) 또는 “Malgun Gothic”(Windows) 글꼴 적용

import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break

plt.rcParams['font.family']
# Out:
# ['AppleGothic']

# %%
a = pd.read_csv('서울시 지도태깅 일자리카페 정보.csv' )#, encoding='CP949')

# %%
b = pd.read_csv('서울특별시 공공도서관 현황정보.csv' )

# %%
c = pd.read_csv('50+재단.csv')

# %%
a.head(1)
# Out:
#                            새주소                   지번주소        좌표정보    좌표정보.1  \
# 0  서울특별시 중구 삼일대로 363 (장교동장교빌딩)  서울특별시 중구 장교동 1번지 장교빌딩  126.987188  37.56709
#
#      테마코드    콘텐츠 코드  \
# 0  100466  cafe_001
#
#   언어셋(KOR : 국문, ENG : 영문, JP : 일문, CHA : 중문-간체, CHB : 중문-번체)       콘텐츠 명  \
# 0                                                KOR          서울시청년일자리센터
#
#   시도명(텍스트)  구명  ...  상세정보 이름 18  상세정보 이름 19  상세정보 이름 20  좌표데이터  \
# 0    서울특별시  중구  ...         NaN         NaN         NaN    NaN
#
#    좌표 타입 (1:Point 3:Polyline 4:MultiPolyline 5:Polygon 6:MultiPolygon 8:multiPoint)  \
# 0                                                  1
#
#   선 두께 1~10  테마 선 색상 키워드                    등록일                    수정일
# 0         4  #0000FF NaN  2018-04-23 14:40:45.0  2018-04-23 14:40:45.0
#
# [1 rows x 63 columns]

# %%
a.columns
# Out:
# Index(['새주소', '지번주소', '좌표정보', '좌표정보.1', '테마코드', '콘텐츠 코드',
#        '언어셋(KOR : 국문, ENG : 영문, JP : 일문, CHA : 중문-간체, CHB : 중문-번체)', '콘텐츠 명',
#        '시도명(텍스트)', '구명', '동명', '산지여부', '주 번지', '부 번지', '기타주소', '전화번호',
#        '상세정보 값 1', '상세정보 값 2', '상세정보 값 3', '상세정보 값 4', '상세정보 값 5', '상세정보 값 6',
#        '상세정보 값 7', '상세정보 값 8', '상세정보 값 9', '상세정보 값 10', '상세정보 값 11',
#        '상세정보 값 12', '상세정보 값 13', '상세정보 값 14', '상세정보 값 15', '상세정보 값 16',
#        '상세정보 값 17', '상세정보 값 18', '상세정보 값 19', '상세정보 값 20', '상세정보 이름 1',
#        '상세정보 이름 2', '상세정보 이름 3', '상세정보 이름 4', '상세정보 이름 5', '상세정보 이름 6',
#        '상세정보 이름 7', '상세정보 이름 8', '상세정보 이름 9', '상세정보 이름 10', '상세정보 이름 11',
#        '상세정보 이름 12', '상세정보 이름 13', '상세정보 이름 14', '상세정보 이름 15', '상세정보 이름 16',
#        '상세정보 이름 17', '상세정보 이름 18', '상세정보 이름 19', '상세정보 이름 20', '좌표데이터',
#        '좌표 타입 (1:Point 3:Polyline 4:MultiPolyline 5:Polygon 6:MultiPolygon 8:multiPoint)',
#        '선 두께 1~10', '테마 선 색상', '키워드', '등록일', '수정일'],
#       dtype='object')

# %%
a1 = [ '지번주소', '좌표정보', '좌표정보.1','콘텐츠 명' ]
aa = a[a1]

# %%
# 지도 준비

from folium import Map
from folium.plugins import HeatMap
map = Map(location=[36.5, 127.5], zoom_start=7)



coordinates = aa[['좌표정보.1', '좌표정보']] #일자리카페는 위도 경도 칼럼이 바껴져 있음! 

coordinates
# Out:
#        좌표정보.1        좌표정보
# 0   37.567090  126.987188
# 1   37.539219  127.067012
# 2   37.505543  127.048911
# 3   37.480521  126.881988
# 4   37.484863  126.840326
# ..        ...         ...
# 85  37.591288  127.020966
# 86  37.495939  126.954376
# 87  37.629213  127.055090
# 88  37.653232  127.048183
# 89  37.526557  127.028803
#
# [90 rows x 2 columns]

# %%
# 지도 준비

map = Map(location=[36.5, 127.5], zoom_start=7)

# 지도에 위치 표시

for lat, lng in coordinates.values:
    marker = folium.Circle(
        location=[lat, lng],
        radius=600,
        weight=1,
        fill_color='#F00', #RGB
        fill_opacity=0.3, #투명도 
    )
    marker.add_to(map)

map
map.save(outfile='노인일자리카페.html')

# %%
map = Map(location=[36.5, 127.5], zoom_start=7)

# 히트맵 표시

HeatMap(data=coordinates, radius=20).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
b.head(1)
# Out:
#    도서관 일련번호       도서관명  구 코드   구명               주소         전화번호 팩스번호  \
# 0      1935  강남구립못골도서관     8  강남구  서울시 강남구 자곡로 116  02-459-5522  NaN
#
#                      홈페이지 URL  운영시간                          정기 휴관일  ...  \
# 0  http://mglib.gangnam.go.kr   NaN  매월 둘째, 넷째 화요일 및 일요일을 제외한 법정공휴일  ...
#
#    도서관 구분명         위도          경도  담당자이메일 도서관 소개 설립연도  회원가입요건 대출안내  교통편 층별 설명
# 0    공공도서관  37.471538  127.096582     NaN    NaN  NaN     NaN  NaN  NaN   NaN
#
# [1 rows x 21 columns]

# %%
b.columns
# Out:
# Index(['도서관 일련번호', '도서관명', '구 코드', '구명', '주소', '전화번호', '팩스번호', '홈페이지 URL',
#        '운영시간', '정기 휴관일', '도서관 구분', '도서관 구분명', '위도', '경도', '담당자이메일', '도서관 소개',
#        '설립연도', '회원가입요건', '대출안내', '교통편', '층별 설명'],
#       dtype='object')

# %%
b1 = [ '도서관명' , '구 코드' ,'위도', '경도']
bb = b[b1]

# %%
coordinates = bb[['위도', '경도']] 

coordinates
# Out:
#             위도          경도
# 0    37.471538  127.096582
# 1    37.496497  127.032027
# 2    37.519099  127.046441
# 3    37.517278  127.037188
# 4    37.498794  127.066997
# ..         ...         ...
# 168  37.560704  127.002151
# 169  37.602663  127.103926
# 170  37.587354  127.087554
# 171  37.615171  127.086906
# 172  37.602663  127.103926
#
# [173 rows x 2 columns]

# %%
# 지도 준비

map = Map(location=[36.5, 127.5], zoom_start=7)

# 지도에 위치 표시

for lat, lng in coordinates.values:
    marker = folium.Circle(
        location=[lat, lng],
        radius=600,
        weight=1,
        fill_color='#F00', #RGB
        fill_opacity=0.3, #투명도 
    )
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save(outfile='공공도서관.html')

# %%
c.head(1)
# Out:
#              캠퍼스                    주소    비고
# 0  서울시 50+ 서부캠퍼스  서울시 은평구 통일로 684(녹번동)  준공예정

# %%
len(c)
# Out:
# 14

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# Window 의 한글 폰트 설정
# plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
plt.rc('font', family='AppleGothic') 
plt.rc('axes', unicode_minus=False)

set_matplotlib_formats('retina')

# %%
import os
import requests

# key = os.environ['KAKAO_REST_API_KEY']

# %%
from geocoder import geocode

# %%
c = c.sample(n=14, random_state=1)

c.shape
# Out:
# (14, 3)

# %%
c.head(1)
# Out:
#              캠퍼스                  주소    비고
# 2  서울시 50+ 동부캠퍼스  서울시 광진구 자양동 57-117  준공예정

# %%
# cc = c.sample(n=14, random_state=1)

# lats = []
# lngs = []

# for i, index in enumerate(cc.index):
#     print(i + 1, '-', index)
#     lat, lng = geocode(cc['주소'][index])
#     lats.append(lat)
#     lngs.append(lng)

# cc = cc.assign(lat=lats, lng=lngs)

# cc.head()
# Out:
# 1 - 6
# 2 - 11
# 3 - 7
# 4 - 1
# 5 - 13
# 6 - 9
# 7 - 12
# 8 - 8
# 9 - 2
# 10 - 4
# 11 - 5
# 12 - 3
# 13 - 0
# 14 - 10
#                 캠퍼스                                      주소    비고        lat  \
# 6    동작50플러스센터 : 센터  서울시 동작구 노량진로 140 메가스터디타워 2층(노량진동 57-1)  준공예정  37.512818
# 11    서울시 50+ 북부캠퍼스                          서울시 도봉구 창동 1-8  준공예정  37.655367
# 7   성북50플러스 센터 : 센터   서울시 성북구 지봉로 24길 26 (보문동 5가 35번지) 3-4층   NaN  37.583859
# 1     서울시 50+ 중부캠퍼스                 서울시 마포구 백범로 31길 21(공덕동)   NaN  37.546747
# 13    서울시 50+ 동남캠퍼스                  서울시 강남구 테헤란로7길 22(역삼동)  준공예정  37.500961
#
#            lng
# 6   126.941667
# 11  127.048013
# 7   127.019247
# 1   126.949974
# 13  127.030621

# %%
cc
# Out:
#                      캠퍼스                                       주소    비고  \
# 6         동작50플러스센터 : 센터   서울시 동작구 노량진로 140 메가스터디타워 2층(노량진동 57-1)  준공예정
# 11         서울시 50+ 북부캠퍼스                           서울시 도봉구 창동 1-8  준공예정
# 7        성북50플러스 센터 : 센터    서울시 성북구 지봉로 24길 26 (보문동 5가 35번지) 3-4층   NaN
# 1          서울시 50+ 중부캠퍼스                  서울시 마포구 백범로 31길 21(공덕동)   NaN
# 13         서울시 50+ 동남캠퍼스                   서울시 강남구 테헤란로7길 22(역삼동)  준공예정
# 9       서대문50플러스 센터 : 센터     서울시 서대문구 통일로 484 (홍은동 48-84) 유진상가 2층   NaN
# 12         서울시 50+ 남부캠퍼스                   서울시 구로구 오류동 156-193외 2   NaN
# 8      광진 50플러스상담센터 : 센터           서울시 광진구 자양로 117 (광진구청 민원복지동2층)   NaN
# 2          서울시 50+ 동부캠퍼스                       서울시 광진구 자양동 57-117  준공예정
# 4         노원50플러스센터 : 센터          서울시 노원구 노원로30길 73 (상계2동 181-14)   NaN
# 5        도심권50플러스센터 : 센터                   서울시 종로구 수표로26길 28 동의빌딩   NaN
# 3   서울시50플러스 남부캠퍼스 : 캠퍼스                        서울시 구로구 오류로 36-25   NaN
# 0          서울시 50+ 서부캠퍼스                     서울시 은평구 통일로 684(녹번동)  준공예정
# 10       영등포50플러스센터 : 센터  서울시 영등포구 여의대방로 372(여의도동 56-1) 여의도복지관 3층   NaN
#
#           lat         lng
# 6   37.512818  126.941667
# 11  37.655367  127.048013
# 7   37.583859  127.019247
# 1   37.546747  126.949974
# 13  37.500961  127.030621
# 9   37.591397  126.942480
# 12  37.487737  126.842130
# 8   37.538400  127.082430
# 2         NaN         NaN
# 4   37.656120  127.070702
# 5   37.572313  126.990496
# 3   37.488641  126.841744
# 0   37.608082  126.933058
# 10  37.518136  126.930759

# %%
# cc.to_csv('cc.csv')

# %%
cc = pd.read_csv('cc.csv')

# %%
map = Map(location=[36.5, 127.5], zoom_start=7)

data = cc[['lat', 'lng']].groupby(['lat', 'lng']).sum().reset_index().values.tolist()

HeatMap(data=data, radius=20).add_to(map)

for lat, lng in data:
    marker = folium.Circle(
        location=[lat, lng],
        radius=500,
        weight=1,
        fill_color='#F00',
        fill_opacity=0.3,
    )
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save(outfile='서울50+.html')

# %%
dong = pd.read_csv('repot_dong1.csv')

# %%
dong.head()
# Out:
#    자치구  행정동      합  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  종로구   소계  44580         NaN         NaN         NaN         NaN
# 1  종로구  사직동   2654         NaN         NaN         NaN         NaN
# 2  종로구  삼청동    841         NaN         NaN         NaN         NaN
# 3  종로구  부암동   2963         NaN         NaN         NaN         NaN
# 4  종로구  평창동   5595         NaN         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 221  Unnamed: 222  \
# 0         NaN         NaN         NaN  ...           NaN           NaN
# 1         NaN         NaN         NaN  ...           NaN           NaN
# 2         NaN         NaN         NaN  ...           NaN           NaN
# 3         NaN         NaN         NaN  ...           NaN           NaN
# 4         NaN         NaN         NaN  ...           NaN           NaN
#
#    Unnamed: 223  Unnamed: 224  Unnamed: 225  Unnamed: 226  Unnamed: 227  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 228  Unnamed: 229  Unnamed: 230
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN
#
# [5 rows x 231 columns]

# %%
dong.columns
# Out:
# Index(['자치구', '행정동', '합', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 245', 'Unnamed: 246', 'Unnamed: 247', 'Unnamed: 248',
#        'Unnamed: 249', 'Unnamed: 250', 'Unnamed: 251', 'Unnamed: 252',
#        'Unnamed: 253', 'Unnamed: 254'],
#       dtype='object', length=255)

# %%
dong1=dong[['자치구', '행정동', '합',]]

# %%
dong1.head()
# Out:
#    자치구  행정동      합
# 0  종로구   소계  44580
# 1  종로구  사직동   2654
# 2  종로구  삼청동    841
# 3  종로구  부암동   2963
# 4  종로구  평창동   5595

# %%
# dong1.to_csv('repot_dong1.csv')

# %%
import json
import matplotlib.pyplot as plt

geo_path = '../skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# 서울시의 중심의 위도와 경도 정보를 먼저 입력하고 경계선을 그리자.

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='stamentoner')
map.choropleth(geo_data=geo_str,
              data=dong1['합'],
              columns=[dong1,dong1['합']],
              fill_color='YlGnBu',
              key_on='feature.id')
map
# map.save('동.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gu = pd.read_csv('repot_gu.csv')

# %%
gu.head(5)
# Out:
#   행정구역별  50~54세  55~59세  60~64세  65~69세     합계
# 0   종로구  12,740  12,971  11,113   7,756  44580
# 1   용산구  18,243  18,169  16,084  10,951  63447
# 2   성동구  24,414  24,611  20,948  13,895  83868
# 3   광진구  28,266  27,985  23,883  15,601  95735
# 4  동대문구  27,150  27,869  25,675  18,270  98964

# %%
geo_path = '../skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# 서울시의 중심의 위도와 경도 정보를 먼저 입력하고 경계선을 그리자.

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='stamentoner')
map.choropleth(geo_data=geo_str,
              data=gu,
              columns=[gu.index,gu['합계']],
              fill_color='YlGnBu',
              key_on='feature.id')
map
# map.save('동.html')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-234630e70376> in <module>
#      10               columns=[gu.index,gu['합계']],
#      11               fill_color='YlGnBu',
# ---> 12               key_on='feature.id')
#      13 map
#      14 # map.save('동.html')
#
# /usr/local/lib/python3.7/site-packages/folium/folium.py in choropleth(self, *args, **kwargs)
#     416         )
#     417         from folium.features import Choropleth
# --> 418         self.add_child(Choropleth(*args, **kwargs))
#     419
#     420     def keep_in_front(self, *args):
#
# /usr/local/lib/python3.7/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1061         if hasattr(data, 'set_index'):
#    1062             # This is a pd.DataFrame
# -> 1063             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#    1064         elif hasattr(data, 'to_dict'):
#    1065             # This is a pd.Series
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2979             if is_iterator(key):
#    2980                 key = list(key)
# -> 2981             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2982
#    2983         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1269                 # When setting, missing keys are not allowed, even with .loc:
#    1270                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1271                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1272         else:
#    1273             try:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1076
#    1077         self._validate_read_indexer(
# -> 1078             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1079         )
#    1080         return keyarr, indexer
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1161                 raise KeyError(
#    1162                     "None of [{key}] are in the [{axis}]".format(
# -> 1163                         key=key, axis=self.obj._get_axis_name(axis)
#    1164                     )
#    1165                 )
#
# KeyError: "None of [Int64Index([ 44580,  63447,  83868,  95735,  98964, 125522, 121462,  97236,\n            105566, 153049, 138456,  85857,  91533, 131191, 162574, 116613,\n             72561, 100631, 106556, 126667, 108308, 136439, 184521, 125692],\n           dtype='int64')] are in the [columns]"
