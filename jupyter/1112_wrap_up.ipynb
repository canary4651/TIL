# %%
import numpy.random

# %%
# 음이항 분포
numpy.random.negative_binomial(10,.4,100) + 10
# 앞면이 10번 나올 확률이 .4일 때, 100명의 사람들이 앞면이 10번 나올 때까지 돌려본 횟수를 구하려면 뒤에 
# n번 나올 때까지 + n번을 더해줘야함.
# Out:
# array([18, 21, 26, 22, 26, 21, 29, 19, 22, 24, 34, 18, 20, 12, 36, 27, 40,
#        30, 32, 25, 36, 39, 26, 24, 25, 32, 21, 25, 32, 18, 16, 39, 19, 17,
#        44, 23, 26, 29, 23, 23, 24, 31, 19, 20, 19, 29, 28, 27, 33, 26, 23,
#        23, 21, 22, 29, 25, 24, 44, 18, 20, 26, 25, 24, 21, 28, 28, 18, 23,
#        26, 30, 21, 23, 19, 24, 20, 27, 19, 27, 30, 32, 24, 19, 18, 29, 28,
#        18, 20, 22, 17, 23, 25, 27, 23, 17, 25, 14, 32, 23, 16, 30])

# %%
numpy.random.geometric(.1,100)
# 성공률이 .1 일 때, 100번 돌렸을 때 성공할 때까지 시도한 총 시도 횟수
# Out:
# array([ 7,  9,  7,  5, 14, 19,  7, 12,  3,  8,  1, 11,  1,  5,  5,  8,  7,
#         1, 15, 12, 11,  2,  3, 24,  2,  8, 16, 14, 27, 55,  2,  1,  5, 11,
#         6,  2,  2, 20,  9,  1, 34, 13,  7,  1,  4,  2, 36, 21, 16,  4,  7,
#        20,  8,  9,  4, 23,  8, 13,  1, 36, 24,  3, 12,  8,  1, 29,  4, 12,
#         5, 55,  6,  2,  3,  3, 12, 21,  6, 15,  6,  4, 12, 10, 11,  1, 13,
#         6,  8,  1,  5,  2,  3, 11,  3, 10,  9,  2, 19,  6,  3, 37])

# %%
# imputation 
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer()

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2],[np.nan,3],[7,6]])

# %%
df
# Out:
#      0  1
# 0  1.0  2
# 1  NaN  3
# 2  7.0  6

# %%
imp.fit_transform(df)
# Out:
# array([[1., 2.],
#        [4., 3.],
#        [7., 6.]])

# %% [markdown]
# # 화재 데이터로 살펴보기

# %%
fire = pd.read_csv('1112_PJT002_train.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_columns',None)

# %%
fire.head()
# Out:
#        id             dt_of_fr    bldng_us bldng_archtctr  bldng_cnt  \
# 0  133759  2015-10-03 02:33:46         NaN            NaN          3
# 1   96248  2016-11-13 17:05:57        업무시설       철근콘크리트구조          3
# 2   71317  2016-11-21 12:46:36        단독주택           블록구조          4
# 3   86638  2016-11-07 02:50:14  위험물저장및처리시설           벽돌구조          2
# 4   97748  2014-01-28 16:36:43         NaN            NaN          4
#
#    bldng_ar   ttl_ar  lnd_ar dt_of_athrztn  ttl_grnd_flr  ttl_dwn_flr  \
# 0    112.86   112.86   200.0           NaN           1.0          0.0
# 1    721.82  1109.54     0.0    1.9881e+07           5.0          0.0
# 2     47.06    47.06   288.0   1.96501e+07           1.0          0.0
# 3    171.45   176.64  1379.0   2.00201e+07           2.0          0.0
# 4      0.00     0.00     0.0           NaN           NaN          NaN
#
#   bldng_us_clssfctn  tmprtr  prcpttn  wnd_spd  wnd_drctn  hmdt  \
# ...

# %%
fire[['bldng_ar','bldng_cnt']]
# Out:
#        bldng_ar  bldng_cnt
# 0        112.86          3
# 1        721.82          3
# 2         47.06          4
# 3        171.45          2
# 4          0.00          4
# ...         ...        ...
# 59194    167.67          1
# 59195     57.38          2
# 59196    126.32          2
# 59197      0.00          4
# 59198    137.67          3
#
# [59199 rows x 2 columns]

# %%
pd.DataFrame(imp.fit_transform(fire[['bldng_ar','bldng_cnt']]))
# 패키지에 따라서 계산하는 방법이 다른데, simpleimputer는 무슨 값으로 했는 지는 찾아야함.
# Out:
#             0    1
# 0      112.86  3.0
# 1      721.82  3.0
# 2       47.06  4.0
# 3      171.45  2.0
# 4        0.00  4.0
# ...       ...  ...
# 59194  167.67  1.0
# 59195   57.38  2.0
# 59196  126.32  2.0
# 59197    0.00  4.0
# 59198  137.67  3.0
#
# [59199 rows x 2 columns]

# %%
from imblearn.over_sampling import SMOTE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-0b052d41b57a> in <module>
# ----> 1 from imblearn.over_sampling import SMOTE
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
ad = SMOTE()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-9494e0b04258> in <module>
# ----> 1 ad = SMOTE()
#
# NameError: name 'SMOTE' is not defined

# %%
X = fire[['blding_cont']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-2735663b119d> in <module>
# ----> 1 X = fire[['blding_cont']]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2979             if is_iterator(key):
#    2980                 key = list(key)
# -> 2981             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2982
#    2983         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1269                 # When setting, missing keys are not allowed, even with .loc:
#    1270                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1271                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1272         else:
# ...

# %%
Y = fire['fr_yn']

# %%
X_res, Y_res = ad.fit_resample(X,Y) # 두 데이터 비율을 1:1로 만들기 # y안에 있는 화재, 비화재 데이터를 반반으로 맞춰줌

# %%
X.shape

# %%
X_res.shape #x와 y 데이터 오버 샘플링 값

# %%
(Y == 'N').mean() # 0.83 정도였는데

# %%
(Y_res == 'N').mean() # 0.5로 맞춰짐

# %%
from imblearn.over_sampling import RandomUnderSampler

# %%
rus = RandomUndersampler()

# %%
X_res, Y_res = rus.fit_resample(X,Y) # 두 데이터 비율을 1:1로 만들기

# %%
# 비워져있는 데이터 수동으로 채우지 마시고 imputation으로 채우세요

# %%
# r 제곱

# %%
df =pd.DataFrame({'x':[1,2,3,4,5], 'y':[1,3,5,3,7]})

# %%
df
# Out:
#    x  y
# 0  1  1
# 1  2  3
# 2  3  5
# 3  4  3
# 4  5  7

# %%
df['y'].var()
# Out:
# 5.2

# %%
df['y'].mean()
# Out:
# 3.8

# %%
1 - np.mean((df['y']-df['x'])**2)/df['y'].var()
# Out:
# 0.6153846153846154

# %%
# 클러스터링
