# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium
# %matplotlib inline
import os
import requests
# key = os.environ['KAKAO_REST_API_KEY']
# LOCATIONIQ_TOKEN = os.environ['LOCATIONIQ_TOKEN']

# %%
# Matplotlib 사용

import matplotlib
import matplotlib.pyplot as plt

matplotlib.__version__
# Out:
# '3.1.0'

# %%
# matplotlib에 “AppleGothc”(Mac) 또는 “Malgun Gothic”(Windows) 글꼴 적용

import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break

plt.rcParams['font.family']
# Out:
# ['AppleGothic']

# %%
a = pd.read_csv('서울시 지도태깅 일자리카페 정보.csv' )#, encoding='CP949')

# %%
b = pd.read_csv('서울특별시 공공도서관 현황정보.csv' )

# %%
c = pd.read_csv('50+재단.csv')

# %%
a.head(1)
# Out:
#                            새주소                   지번주소        좌표정보    좌표정보.1  \
# 0  서울특별시 중구 삼일대로 363 (장교동장교빌딩)  서울특별시 중구 장교동 1번지 장교빌딩  126.987188  37.56709
#
#      테마코드    콘텐츠 코드  \
# 0  100466  cafe_001
#
#   언어셋(KOR : 국문, ENG : 영문, JP : 일문, CHA : 중문-간체, CHB : 중문-번체)       콘텐츠 명  \
# 0                                                KOR          서울시청년일자리센터
#
#   시도명(텍스트)  구명  ...  상세정보 이름 18  상세정보 이름 19  상세정보 이름 20  좌표데이터  \
# 0    서울특별시  중구  ...         NaN         NaN         NaN    NaN
#
#    좌표 타입 (1:Point 3:Polyline 4:MultiPolyline 5:Polygon 6:MultiPolygon 8:multiPoint)  \
# 0                                                  1
#
#   선 두께 1~10  테마 선 색상 키워드                    등록일                    수정일
# 0         4  #0000FF NaN  2018-04-23 14:40:45.0  2018-04-23 14:40:45.0
#
# [1 rows x 63 columns]

# %%
a.columns
# Out:
# Index(['새주소', '지번주소', '좌표정보', '좌표정보.1', '테마코드', '콘텐츠 코드',
#        '언어셋(KOR : 국문, ENG : 영문, JP : 일문, CHA : 중문-간체, CHB : 중문-번체)', '콘텐츠 명',
#        '시도명(텍스트)', '구명', '동명', '산지여부', '주 번지', '부 번지', '기타주소', '전화번호',
#        '상세정보 값 1', '상세정보 값 2', '상세정보 값 3', '상세정보 값 4', '상세정보 값 5', '상세정보 값 6',
#        '상세정보 값 7', '상세정보 값 8', '상세정보 값 9', '상세정보 값 10', '상세정보 값 11',
#        '상세정보 값 12', '상세정보 값 13', '상세정보 값 14', '상세정보 값 15', '상세정보 값 16',
#        '상세정보 값 17', '상세정보 값 18', '상세정보 값 19', '상세정보 값 20', '상세정보 이름 1',
#        '상세정보 이름 2', '상세정보 이름 3', '상세정보 이름 4', '상세정보 이름 5', '상세정보 이름 6',
#        '상세정보 이름 7', '상세정보 이름 8', '상세정보 이름 9', '상세정보 이름 10', '상세정보 이름 11',
#        '상세정보 이름 12', '상세정보 이름 13', '상세정보 이름 14', '상세정보 이름 15', '상세정보 이름 16',
#        '상세정보 이름 17', '상세정보 이름 18', '상세정보 이름 19', '상세정보 이름 20', '좌표데이터',
#        '좌표 타입 (1:Point 3:Polyline 4:MultiPolyline 5:Polygon 6:MultiPolygon 8:multiPoint)',
#        '선 두께 1~10', '테마 선 색상', '키워드', '등록일', '수정일'],
#       dtype='object')

# %%
a1 = [ '지번주소', '좌표정보', '좌표정보.1','콘텐츠 명' ]
aa = a[a1]

# %%
# 지도 준비

from folium import Map
# from folium.plugins import HeatMap
# map = Map(location=[36.5, 127.5], zoom_start=7)



coordinates = aa[['좌표정보.1', '좌표정보']] #일자리카페는 위도 경도 칼럼이 바껴져 있음! 

coordinates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-aaf4056fea49> in <module>
#       7
#       8
# ----> 9 coordinates = aa[['좌표정보.1', '좌표정보']] #일자리카페는 위도 경도 칼럼이 바껴져 있음!
#      10
#      11 coordinates
#
# NameError: name 'aa' is not defined

# %%
# 지도 준비

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
               tiles='Stamen Terrain')

# 지도에 위치 표시

fg = folium.FeatureGroup(name = '노인일자리카페')
for lat, lon, name in zip(aa['좌표정보.1'], aa['좌표정보'],aa['콘텐츠 명']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'blue', icon_color = 'white')))
map.add_child(fg)



# for lat, lng in coordinates.values:
#     marker = folium.Circle(
#         folium.Marker(location=coordinates,
#         popup=(Fg),
#         icon=folium.Icon(icon = 'star', color= 'blue', icon_color = 'white')),
#         radius=600,
#         weight=1,
#         fill_color='#F00', #RGB
#         fill_opacity=0.3, #투명도 
#     )
#     marker.add_to(map)

# map.add_child(fg)
map
#map.save(outfile='노인일자리카페.html')

# map = folium.Map(location=[35.9078, 127.7669], zoom_start = 6, tiles ='Mapbox bright')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# map = Map(location=[36.5, 127.5], zoom_start=7)

# # 히트맵 표시

# HeatMap(data=coordinates, radius=20).add_to(map)

# map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
b.head(1)
# Out:
#    도서관 일련번호       도서관명  구 코드   구명               주소         전화번호 팩스번호  \
# 0      1935  강남구립못골도서관     8  강남구  서울시 강남구 자곡로 116  02-459-5522  NaN
#
#                      홈페이지 URL  운영시간                          정기 휴관일  ...  \
# 0  http://mglib.gangnam.go.kr   NaN  매월 둘째, 넷째 화요일 및 일요일을 제외한 법정공휴일  ...
#
#    도서관 구분명         위도          경도  담당자이메일 도서관 소개 설립연도  회원가입요건 대출안내  교통편 층별 설명
# 0    공공도서관  37.471538  127.096582     NaN    NaN  NaN     NaN  NaN  NaN   NaN
#
# [1 rows x 21 columns]

# %%
b.columns
# Out:
# Index(['도서관 일련번호', '도서관명', '구 코드', '구명', '주소', '전화번호', '팩스번호', '홈페이지 URL',
#        '운영시간', '정기 휴관일', '도서관 구분', '도서관 구분명', '위도', '경도', '담당자이메일', '도서관 소개',
#        '설립연도', '회원가입요건', '대출안내', '교통편', '층별 설명'],
#       dtype='object')

# %%
b1 = [ '도서관명' , '구명' ,'위도', '경도']
bb = b[b1]

# %%
coordinates = bb[['위도', '경도']] 

coordinates
# Out:
#             위도          경도
# 0    37.471538  127.096582
# 1    37.496497  127.032027
# 2    37.519099  127.046441
# 3    37.517278  127.037188
# 4    37.498794  127.066997
# ..         ...         ...
# 168  37.560704  127.002151
# 169  37.602663  127.103926
# 170  37.587354  127.087554
# 171  37.615171  127.086906
# 172  37.602663  127.103926
#
# [173 rows x 2 columns]

# %%
# 지도 준비

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
               tiles='Stamen Terrain')

    
fg = folium.FeatureGroup(name = '도서관')
for lat, lon, name in zip(bb['위도'], bb['경도'],bb['도서관명']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'green', icon_color = 'white')))
map.add_child(fg)
    
map
# map.save(outfile='도서관.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save(outfile='공공도서관.html')

# %%
c.head(1)
# Out:
#              캠퍼스                    주소    비고
# 0  서울시 50+ 서부캠퍼스  서울시 은평구 통일로 684(녹번동)  준공예정

# %%
len(c)
# Out:
# 14

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import folium
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# Window 의 한글 폰트 설정
# plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
plt.rc('font', family='AppleGothic') 
plt.rc('axes', unicode_minus=False)

set_matplotlib_formats('retina')

# %%
import os
import requests

# key = os.environ['KAKAO_REST_API_KEY']

# %%
from geocoder import geocode
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-5657a441bbdb> in <module>
# ----> 1 from geocoder import geocode
#
# ~/Desktop/Yeeunhan/jupyter/빅데이터/geocoder.py in <module>
#       3
#       4
# ----> 5 key = os.environ['KAKAO_REST_API_KEY']
#       6
#       7
#
# /usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'KAKAO_REST_API_KEY'

# %%
c = c.sample(n=14, random_state=1)

c.shape
# Out:
# (14, 3)

# %%
c.head(1)
# Out:
#                     캠퍼스                 주소   비고
# 3  서울시50플러스 남부캠퍼스 : 캠퍼스  서울시 구로구 오류로 36-25  NaN

# %%
# cc = c.sample(n=14, random_state=1)

# lats = []
# lngs = []

# for i, index in enumerate(cc.index):
#     print(i + 1, '-', index)
#     lat, lng = geocode(cc['주소'][index])
#     lats.append(lat)
#     lngs.append(lng)

# cc = cc.assign(lat=lats, lng=lngs)

# cc.head()

# %%
# cc.to_csv('cc.csv')

# %%
cc = pd.read_csv('cc.csv')

# %%
cc.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1              캠퍼스  \
# 0           0             6   동작50플러스센터 : 센터
# 1           1            11    서울시 50+ 북부캠퍼스
# 2           2             7  성북50플러스 센터 : 센터
# 3           3             1    서울시 50+ 중부캠퍼스
# 4           4            13    서울시 50+ 동남캠퍼스
#
#                                        주소    비고        lat         lng  \
# 0  서울시 동작구 노량진로 140 메가스터디타워 2층(노량진동 57-1)  준공예정  37.512818  126.941667
# 1                          서울시 도봉구 창동 1-8  준공예정  37.655367  127.048013
# 2   서울시 성북구 지봉로 24길 26 (보문동 5가 35번지) 3-4층   NaN  37.583859  127.019247
# 3                 서울시 마포구 백범로 31길 21(공덕동)   NaN  37.546747  126.949974
# 4                  서울시 강남구 테헤란로7길 22(역삼동)  준공예정  37.500961  127.030621
#
#   sigungu  count
# 0     동작구      1
# 1     도봉구      1
# 2     성북구      1
# 3     마포구      1
# 4     강남구      1

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='Stamen Terrain') # tiles='Stamen Terrain''stamentoner'
fg = folium.FeatureGroup(name = '50+t센터')
for lat, lon, name in zip(cc['lat'], cc['lng'],cc['캠퍼스']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'pink', icon_color = 'white')))
map.add_child(fg)

map
#map.save(outfile='50+.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save(outfile='서울50+.html')

# %%
dong = pd.read_csv('repot_dong1.csv')

# %%
dong.head()
# Out:
#    자치구  행정동      합  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  종로구   소계  44580         NaN         NaN         NaN         NaN
# 1  종로구  사직동   2654         NaN         NaN         NaN         NaN
# 2  종로구  삼청동    841         NaN         NaN         NaN         NaN
# 3  종로구  부암동   2963         NaN         NaN         NaN         NaN
# 4  종로구  평창동   5595         NaN         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 221  Unnamed: 222  \
# 0         NaN         NaN         NaN  ...           NaN           NaN
# 1         NaN         NaN         NaN  ...           NaN           NaN
# 2         NaN         NaN         NaN  ...           NaN           NaN
# 3         NaN         NaN         NaN  ...           NaN           NaN
# 4         NaN         NaN         NaN  ...           NaN           NaN
#
#    Unnamed: 223  Unnamed: 224  Unnamed: 225  Unnamed: 226  Unnamed: 227  \
# ...

# %%
dong.columns
# Out:
# Index(['자치구', '행정동', '합', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 221', 'Unnamed: 222', 'Unnamed: 223', 'Unnamed: 224',
#        'Unnamed: 225', 'Unnamed: 226', 'Unnamed: 227', 'Unnamed: 228',
#        'Unnamed: 229', 'Unnamed: 230'],
#       dtype='object', length=231)

# %%
dong1=dong[['자치구', '행정동', '합',]]

# %%
dong1.head()
# Out:
#    자치구  행정동      합
# 0  종로구   소계  44580
# 1  종로구  사직동   2654
# 2  종로구  삼청동    841
# 3  종로구  부암동   2963
# 4  종로구  평창동   5595

# %%
# dong1.to_csv('repot_dong1.csv')

# %%
# import json
# import matplotlib.pyplot as plt

# geo_path = '../skorea_submunicipalities_geo_simple1.json'
# geo_str = json.load(open(geo_path, encoding='utf-8'))

# # 서울시의 중심의 위도와 경도 정보를 먼저 입력하고 경계선을 그리자.

# map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
#                 tiles='stamentoner')
# map.choropleth(geo_data=geo_str,
#               data=dong1,
#               columns=['행정동','합'],
#               fill_color='YlGnBu',
#               key_on='properties.code')
# map
# map.save('동.html')

# %%
gu = pd.read_csv('repot_gu.csv', encoding = "CP949")

# %%
gu.head(5)
# Out:
#   행정구역별  50~54세  55~59세  60~64세  65~69세     합계
# 0   종로구  12,740  12,971  11,113   7,756  44580
# 1   용산구  18,243  18,169  16,084  10,951  63447
# 2   성동구  24,414  24,611  20,948  13,895  83868
# 3   광진구  28,266  27,985  23,883  15,601  95735
# 4  동대문구  27,150  27,869  25,675  18,270  98964

# %%
import json
geo_path = '../skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# 서울시의 중심의 위도와 경도 정보를 먼저 입력하고 경계선을 그리자.

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='stamentoner') # tiles='Stamen Terrain'
map.choropleth(geo_data=geo_str,
              data=gu,
              columns=['행정구역별','합계'],
              fill_color='YlGnBu',
              # label=gu.iloc[:]['행정구역별'],
              key_on='feature.id',
              legend_name='population(people)')

# geo_c = cc
# for n in geo_c.index:
# #     # 팝업에 들어갈 텍스트를 지정해 줍니다.
#     popup_name = geo_c.loc[n, '캠퍼스'] + ' - ' + geo_c.loc[n, 'sigungu']
# #     # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
#     #if geo_df.loc[n, '브랜드명'] == '스타벅스' :
#         #icon_color = 'green'    

            
        # folium.CircleMarker 혹은 folium.features.CircleMarker 오류가 날 경우
        # --> folium.vector_layer.CircleMarker 를 사용합니다.
#     folium.CircleMarker(
#             location=[geo_c.loc[n,'lat'], geo_c.loc[n, 'lng']],
#             radius=3,
#             popup=popup_name,
#             color= 'green',
#             fill=True,
#             fill_color='green'
#         ).add_to(map)
    

# for n in bb.index:
#     # 팝업에 들어갈 텍스트를 지정해 줍니다.
#     popup_name = bb.loc[n, '도서관명'] + ' - ' + bb.loc[n, '구명']
#     # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
#    # if geo_df.loc[n, '브랜드명'] == '스타벅스' :
#     #    icon_color = 'green'    

            
#         #folium.CircleMarker 혹은 folium.features.CircleMarker 오류가 날 경우
#         #--> folium.vector_layer.CircleMarker 를 사용합니다.
# folium.CircleMarker(
#     location=[bb.loc[n,'위도'], bb.loc[n, '경도']],
#     radius=3,
#     popup=popup_name,
#     color= 'blue',
#     fill=True,
#     fill_color='blue'
# ).add_to(map)
    
    

map
map.save('노인인구수.png')
#map.save('노인인구수.html')

# %%
def get_sigungu(x):
    return x.split()[1]

# %%
sigungu = []
for i, v in cc['주소'].items():
    sigungu.append(get_sigungu(v))

# %%
cc['sigungu'] = sigungu

# %%
cc['count'] = 1

# %%
cc['lat'][8] = '37.534345'
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cc['lng'][8] = '127.062441'
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cc

# %%
# cc.to_csv('cc.csv')

# %%
geo_c = cc
for n in geo_c.index:
#     # 팝업에 들어갈 텍스트를 지정해 줍니다.
    popup_name = geo_c.loc[n, '캠퍼스'] + ' - ' + geo_c.loc[n, 'sigungu']
#     # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
    #if geo_df.loc[n, '브랜드명'] == '스타벅스' :
        #icon_color = 'green'    

            
        # folium.CircleMarker 혹은 folium.features.CircleMarker 오류가 날 경우
        # --> folium.vector_layer.CircleMarker 를 사용합니다.
    folium.CircleMarker(
            location=[geo_c.loc[n,'lat'], geo_c.loc[n, 'lng']],
            radius=3,
            popup=popup_name,
            color= 'green',
            fill=True,
            fill_color='green'
        ).add_to(map)
    
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(bb)
# Out:
# 173

# %%
bb.head()
# Out:
#          도서관명   구명         위도          경도
# 0   강남구립못골도서관  강남구  37.471538  127.096582
# 1  강남역삼푸른솔도서관  강남구  37.496497  127.032027
# 2      정다운도서관  강남구  37.519099  127.046441
# 3       논현도서관  강남구  37.517278  127.037188
# 4       대치도서관  강남구  37.498794  127.066997

# %%
for n in bb.index:
    # 팝업에 들어갈 텍스트를 지정해 줍니다.
    popup_name = bb.loc[n, '도서관명'] + ' - ' + bb.loc[n, '구명']
    # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
   # if geo_df.loc[n, '브랜드명'] == '스타벅스' :
    #    icon_color = 'green'    

            
        #folium.CircleMarker 혹은 folium.features.CircleMarker 오류가 날 경우
        #--> folium.vector_layer.CircleMarker 를 사용합니다.
folium.CircleMarker(
    location=[bb.loc[n,'위도'], bb.loc[n, '경도']],
    radius=3,
    popup=popup_name,
    color= 'blue',
    fill=True,
    fill_color='blue'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
aa.head()
# Out:
#                                  지번주소        좌표정보     좌표정보.1       콘텐츠 명
# 0               서울특별시 중구 장교동 1번지 장교빌딩  126.987188  37.567090  서울시청년일자리센터
# 1  서울특별시 광진구 자양동 9-13번지 서울특별시동부여성발전센타  127.067012  37.539219    동부여성발전센터
# 2            서울특별시 강남구 삼성동 141번지 성원빌딩  127.048911  37.505543  LH강남권마이홈센터
# 3     서울특별시 금천구 가산동 371-28번지 우림라이온스밸리  126.881988  37.480521   무중력지대 G밸리
# 4               서울특별시 구로구 천왕동 13-56번지  126.840326  37.484863        버들마을

# %%
for n in aa.index:
    # 팝업에 들어갈 텍스트를 지정해 줍니다.
    popup_name = aa.loc[n, '콘텐츠 명'] + ' - ' + aa.loc[n, '지번주소']
    # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
   # if geo_df.loc[n, '브랜드명'] == '스타벅스' :
    #    icon_color = 'green'    

            
        #folium.CircleMarker 혹은 folium.features.CircleMarker 오류가 날 경우
        #--> folium.vector_layer.CircleMarker 를 사용합니다.
folium.CircleMarker(
    location=[aa.loc[n,'좌표정보.1'], aa.loc[n, '좌표정보']],
    radius=3,
    popup=popup_name,
    color= 'red',
    fill=True,
    fill_color='red'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gg = pd.read_csv('각지표별점수_191017.csv')

# %%
gg.head()
# Out:
#   Unnamed: 0   Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      행 레이블         점수합산         NaN        NaN         NaN         NaN
# 1        종로구          300         NaN        NaN         NaN         NaN
# 2         중구  291.3851733         NaN        NaN         NaN         NaN
# 3       영등포구  177.5851722         NaN        NaN         NaN         NaN
# 4        강남구  164.2671948         NaN        NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN

# %%
gg1 = gg[['Unnamed: 0','Unnamed: 1']]

# %%
gg1.columns = ['구','점수합산']

# %%
gg1
# Out:
#         구         점수합산
# 0   행 레이블         점수합산
# 1     종로구          300
# 2      중구  291.3851733
# 3    영등포구  177.5851722
# 4     강남구  164.2671948
# 5     서초구  152.9238602
# 6     관악구  151.2341375
# 7    동대문구  139.0551069
# 8     마포구   113.489684
# 9     구로구  111.1670772
# 10   서대문구  109.0351546
# 11    광진구  99.83943971
# 12    도봉구  98.20490994
# 13    강북구  97.86245519
# 14    용산구  95.59690827
# 15    성북구   91.4020991
# 16    성동구   88.4728221
# 17    금천구  87.61795454
# 18    동작구  83.37964079
# 19    송파구  81.31387812
# 20    강서구  70.58955145
# 21    양천구  68.35361325
# 22    강동구  66.01405301
# 23    노원구  62.86155525
# 24    중랑구  56.49595594
# 25    은평구  47.65581759
# 26    NaN          NaN
# 27    NaN          NaN
# 28    NaN          NaN
# 29    NaN          NaN
# 30    NaN          NaN
# 31    NaN          NaN
# 32    NaN          NaN
# 33    NaN          NaN
# 34    NaN          NaN
# 35    NaN          NaN
# 36    NaN          NaN
# 37    NaN          NaN
# 38    NaN          NaN
# ...

# %%
gg2 = gg1.loc[1:25]

# %%
gg2
# Out:
#        구         점수합산
# 1    종로구          300
# 2     중구  291.3851733
# 3   영등포구  177.5851722
# 4    강남구  164.2671948
# 5    서초구  152.9238602
# 6    관악구  151.2341375
# 7   동대문구  139.0551069
# 8    마포구   113.489684
# 9    구로구  111.1670772
# 10  서대문구  109.0351546
# 11   광진구  99.83943971
# 12   도봉구  98.20490994
# 13   강북구  97.86245519
# 14   용산구  95.59690827
# 15   성북구   91.4020991
# 16   성동구   88.4728221
# 17   금천구  87.61795454
# 18   동작구  83.37964079
# 19   송파구  81.31387812
# 20   강서구  70.58955145
# 21   양천구  68.35361325
# 22   강동구  66.01405301
# 23   노원구  62.86155525
# 24   중랑구  56.49595594
# 25   은평구  47.65581759

# %%
#gg2.to_csv('지표화.csv')

# %%
sc = pd.read_csv('지표화.csv')

# %%
sc.head()
# Out:
#    Unnamed: 0     구        점수합산
# 0           1   종로구  300.000000
# 1           2    중구  291.385173
# 2           3  영등포구  177.585172
# 3           4   강남구  164.267195
# 4           5   서초구  152.923860

# %%
sc['점수합산'] = 300 - sc['점수합산']

# %%
sc.head()
# Out:
#    Unnamed: 0     구        점수합산
# 0           1   종로구    0.000000
# 1           2    중구    8.614827
# 2           3  영등포구  122.414828
# 3           4   강남구  135.732805
# 4           5   서초구  147.076140

# %%
geo_path = '../skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# 서울시의 중심의 위도와 경도 정보를 먼저 입력하고 경계선을 그리자.

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='Stamen Terrain') # tiles='Stamen Terrain''stamentoner'
map.choropleth(geo_data=geo_str,
              data=sc,
              columns=['구','점수합산'],
              fill_color='YlOrRd', 
              # label=gu.iloc[:]['행정구역별'],
              key_on='feature.id',
              legend_name='population(people)')


fg = folium.FeatureGroup(name = '노인일자리카페')
for lat, lon, name in zip(aa['좌표정보.1'], aa['좌표정보'],aa['콘텐츠 명']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'blue', icon_color = 'white')))
map.add_child(fg)

fg = folium.FeatureGroup(name = '도서관')
for lat, lon, name in zip(bb['위도'], bb['경도'],bb['도서관명']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'green', icon_color = 'white')))
map.add_child(fg)

fg = folium.FeatureGroup(name = '50+t센터')
for lat, lon, name in zip(cc['lat'], cc['lng'],cc['캠퍼스']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'pink', icon_color = 'white')))
map.add_child(fg)

    
map
# map.save('지표화지도_마커표시.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dd = pd.read_csv('평생교육기관.csv')

# %%
dd.head()
# Out:
#    자치구  프로그램수
# 0  종로구  3,656
# 1   중구  4,769
# 2  용산구  2,151
# 3  성동구  2,494
# 4  광진구  3,017

# %%
len(dd)
# Out:
# 25

# %%
dd = dd.sample(n=25, random_state=1)

lats = []
lngs = []

for i, index in enumerate(dd.index):
    print(i + 1, '-', index)
    lat, lng = geocode(dd['자치구'][index])
    lats.append(lat)
    lngs.append(lng)

dd = dd.assign(lat=lats, lng=lngs)

dd.head()
# Out:
# 1 - 14
# 2 - 13
# 3 - 17
# 4 - 3
# 5 - 21
# 6 - 10
# 7 - 18
# 8 - 19
# 9 - 4
# 10 - 2
# 11 - 20
# 12 - 6
# 13 - 7
# 14 - 22
# 15 - 1
# 16 - 16
# 17 - 0
# 18 - 15
# 19 - 24
# 20 - 23
# 21 - 9
# 22 - 8
# 23 - 12
# 24 - 11
# 25 - 5
#     자치구   프로그램수        lat         lng
# 14  양천구   2,606  37.516988  126.866501
# 13  마포구   4,378  37.566214  126.901955
# 17  금천구   2,211  37.456841  126.895457
# 3   성동구   2,494  37.563427  127.036930
# 21  서초구  19,534  37.483592  127.032694

# %%
dd.to_csv('dd2.csv')

# %%
hh = pd.read_csv('구별점수.csv')

# %%
hh.head()
# Out:
#   행 레이블   합계
# 0   강남구  300
# 1   관악구  256
# 2  영등포구  239
# 3   서초구  222
# 4   송파구  201

# %%
geo_path = '../skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# 서울시의 중심의 위도와 경도 정보를 먼저 입력하고 경계선을 그리자.

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='Stamen Terrain') # tiles='Stamen Terrain''stamentoner'
map.choropleth(geo_data=geo_str,
              data=hh,
              columns=['행 레이블','합계'],
              fill_color='PuRd', 
              # label=gu.iloc[:]['행정구역별'],
              key_on='feature.id')
              # legend_name='population(people)')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
hh['합계'] = 300 - hh['합계']

# %%
hh.head()
# Out:
#   행 레이블  합계
# 0   강남구   0
# 1   관악구  44
# 2  영등포구  61
# 3   서초구  78
# 4   송파구  99

# %%
geo_path = '../skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# 서울시의 중심의 위도와 경도 정보를 먼저 입력하고 경계선을 그리자.

map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                tiles='Stamen Terrain') # tiles='Stamen Terrain''stamentoner'
map.choropleth(geo_data=geo_str,
              data=hh,
              columns=['행 레이블','합계'],
              fill_color='PuRd', 
              # label=gu.iloc[:]['행정구역별'],
              key_on='feature.id')
              # legend_name='population(people)')
map
#map.save('지표화지도_인구수전.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
