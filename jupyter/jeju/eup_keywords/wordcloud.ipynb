# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np 
from PIL import Image

# %%
text = open('구좌읍_키워드.txt').read()
mask = np.array(Image.open('carrot.png'))

stopwords =set(STOPWORDS)
# stopwords.add('said')

# %%
import matplotlib.pyplot as plt
import platform

path = '/Library/Fonts/AppleGothic.ttf'
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system()== 'Library':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family = font_name)
else:
    print('Unknow ststem..')


# for font in fm.fontManager.ttflist:
#     if font.name in ['AppleGothic', 'Malgun Gothic']:
#         plt.rcParams['font.family'] = font.name
#         break

# plt.rcParams['font.family']

# %matplotlib inline

# %%
plt.figure(figsize=(8,8))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear') #cmap=plt.cm.gray
plt.axis('off')
plt.show()

# %%
icon = (Image.open('carrot4.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=80
               , mask=mask).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('carrot4.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("Yun_Dongju.png")

# %%
# wc.to_file("구좌.png")

# %% [markdown]
# # 우도

# %%
text = open('우도_키워드.txt').read()

icon = (Image.open('peanut.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=80
               , mask=mask,random_state=42).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('peanut.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("Yun_Dongju.png")

# %%
# wc.to_file("우도.png")

# %% [markdown]
# # 애월읍

# %%
text = open('애월읍_키워드.txt').read()

icon = (Image.open('hanla3.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=80
               , mask=mask,random_state=42).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('hanla3.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("Yun_Dongju.png")

# %%
# wc.to_file("애월읍.png")

# %% [markdown]
# # 대정읍

# %%
text = open('대정읍_키워드.txt').read()

icon = (Image.open('dol.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=100
               , mask=mask,random_state=42).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('dol.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("Yun_Dongju.png")

# %%
# wc.to_file("대정읍.png")

# %% [markdown]
# # 성산읍

# %%
text = open('성산읍_키워드.txt').read()

icon = (Image.open('seong.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=50
               , mask=mask,random_state=300).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('seong.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("읍.png")

# %%
# wc.to_file("성산읍.png")

# %% [markdown]
# # 대정읍

# %%
text = open('대정읍_키워드.txt').read()

icon = (Image.open('horse.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=500
               , mask=mask,random_state=300).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('horse.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("읍.png")

# %%
# wc.to_file("대정읍.png")

# %% [markdown]
# # 안덕면

# %%
text = open('안덕면_키워드.txt').read()

icon = (Image.open('pig.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=120
               , mask=mask,random_state=100).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('pig.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("읍.png")

# %%
# wc.to_file("안덕면.png")

# %% [markdown]
# # 조천읍

# %%
text = open('조천읍_키워드.txt').read()

icon = (Image.open('hae.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=200
               , mask=mask,random_state=42).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('hae.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("읍.png")

# %%
# wc.to_file('조천읍.png')

# %% [markdown]
# # 표선면

# %%
text = open('표선면_키워드.txt').read()

icon = (Image.open('su.png'))       #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
#                max_words=2000, 
               max_font_size=300
               , mask=mask,random_state=100).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('su.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("읍.png")

# %%
# wc.to_file("표선면.png")

# %% [markdown]
# # 한경읍

# %%
text = open('한경읍_키워드.txt').read()

icon = (Image.open('windmill2.png')) #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
                min_font_size=10, 
                max_font_size=500,
               mask=mask,random_state=42).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('windmill2.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("읍.png")

# %%
# wc.to_file("한경읍.png")

# %% [markdown]
# # 한립읍

# %%
text = open('한림읍_키워드.txt').read()

icon = (Image.open('Dong.png')) #.convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)
# mask = np.array(Image.open('carrot4.png'))
wc = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
               background_color='white', 
                min_font_size=10, 
                max_font_size=70,
               mask=mask,random_state=42).generate(text)
# wc = wc.generate(text)
# wc.generate_from_text(text)
# wc.recolor(color_func=color_func, random_state=3) wc.recolor(color_func=image_colors)
# wc.words_
coloring = np.array(Image.open('Dong.png'))
image_colors = ImageColorGenerator(coloring)
image_colors.default_color = [0.6,0.6,0.6]
wc.recolor(None,image_colors)

plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear' )
plt.axis('off')
plt.show()
# wc.to_file("읍.png")

# %%
# wc.to_file("한림읍.png")
