# %%
import numpy as np
import pandas as pd

# %%
a = pd.read_csv('상권배후지-추정유동인구(2019년).csv', encoding='CP949')

# %%
a.head()
# Out:
#    stdr_yy_cd  stdr_qu_cd trdar_se_cd trdar_se_cd_nm  trdar_cd trdar_cd_nm  \
# 0        2019           1           A           골목상권   1000948    백제고분로34길
# 1        2019           1           A           골목상권   1000949    백제고분로39길
# 2        2019           1           A           골목상권   1000950    백제고분로42길
# 3        2019           1           A           골목상권   1000951    백제고분로45길
# 4        2019           1           A           골목상권   1000952    백제고분로46길
#
#    tot_flpop_co  ml_flpop_co  fml_flpop_co  agrde_10_flpop_co  ...  \
# 0        891686       458778        432913              27424  ...
# 1       1350290       664267        686024              60609  ...
# 2       1537065       746194        790871             107321  ...
# 3       2034278      1011486       1022793              80721  ...
# 4       1700466       832267        868198             109671  ...
#
#    fag_60_above_sattm_3_flpop_co  fag_60_above_sattm_4_flpop_co  \
# 0                           1494                           1363
# 1                           2645                           2297
# 2                           2662                           2604
# 3                           3303                           3096
# 4                           3110                           3028
#
#    fag_60_above_sattm_5_flpop_co  fag_60_above_sattm_6_flpop_co  \
# 0                           1537                            854
# 1                           2477                           1124
# 2                           2928                           1373
# 3                           3915                           1923
# 4                           3634                           1954
#
#    fag_60_above_suntm_1_flpop_co  fag_60_above_suntm_2_flpop_co  \
# 0                           1393                           1941
# 1                           1707                           2509
# 2                           2269                           2591
# 3                           3015                           3072
# 4                           3414                           3803
#
#    fag_60_above_suntm_3_flpop_co  fag_60_above_suntm_4_flpop_co  \
# 0                           1944                           1515
# 1                           3710                           2505
# 2                           2612                           2503
# 3                           3108                           2935
# 4                           3472                           2991
#
#    fag_60_above_suntm_5_flpop_co  fag_60_above_suntm_6_flpop_co
# 0                           1383                            668
# 1                           2157                            883
# 2                           2554                           1098
# 3                           3532                           1630
# 4                           3483                           1781
#
# [5 rows x 532 columns]

# %%
a.columns
# Out:
# Index(['stdr_yy_cd', 'stdr_qu_cd', 'trdar_se_cd', 'trdar_se_cd_nm', 'trdar_cd',
#        'trdar_cd_nm', 'tot_flpop_co', 'ml_flpop_co', 'fml_flpop_co',
#        'agrde_10_flpop_co',
#        ...
#        'fag_60_above_sattm_3_flpop_co', 'fag_60_above_sattm_4_flpop_co',
#        'fag_60_above_sattm_5_flpop_co', 'fag_60_above_sattm_6_flpop_co',
#        'fag_60_above_suntm_1_flpop_co', 'fag_60_above_suntm_2_flpop_co',
#        'fag_60_above_suntm_3_flpop_co', 'fag_60_above_suntm_4_flpop_co',
#        'fag_60_above_suntm_5_flpop_co', 'fag_60_above_suntm_6_flpop_co'],
#       dtype='object', length=532)

# %%
a1 = ['trdar_se_cd_nm','trdar_cd_nm','tot_flpop_co','ml_flpop_co'
      ,'fml_flpop_co','agrde_20_flpop_co','agrde_30_flpop_co','agrde_40_flpop_co'
      ,'agrde_50_flpop_co']
aa = a[a1]
# Out:
#      trdar_se_cd_nm trdar_cd_nm  tot_flpop_co  ml_flpop_co  fml_flpop_co  \
# 0              골목상권    백제고분로34길        891686       458778        432913
# 1              골목상권    백제고분로39길       1350290       664267        686024
# 2              골목상권    백제고분로42길       1537065       746194        790871
# 3              골목상권    백제고분로45길       2034278      1011486       1022793
# 4              골목상권    백제고분로46길       1700466       832267        868198
# ...             ...         ...           ...          ...           ...
# 1005           골목상권    천호대로162길       3214980      1578350       1636628
# 1006           골목상권    천호대로170길       3255534      1645745       1609790
# 1007           골목상권      천호옛14길       3204360      1511917       1692444
# 1008           골목상권        천호옛길       3070192      1485625       1584578
# 1009           골목상권     풍성로37가길       2607258      1287202       1320057
#
#       agrde_20_flpop_co  agrde_30_flpop_co  agrde_40_flpop_co  \
# 0                200897             222019             164050
# 1                314008             316896             224150
# 2                364109             323153             239255
# 3                571739             484153             312444
# 4                383186             360773             273150
# ...                 ...                ...                ...
# 1005             848189             653189             504567
# 1006             672735             660941             591114
# 1007             815682             639820             501482
# 1008             660927             610258             521454
# 1009             565318             522803             455473
#
#       agrde_50_flpop_co
# 0                153462
# 1                230418
# 2                265241
# 3                306971
# 4                296763
# ...                 ...
# 1005             548544
# 1006             613136
# 1007             563594
# 1008             577013
# 1009             481943
#
# [1010 rows x 9 columns]

# %%
aa.max()
# Out:
# trdar_se_cd_nm          골목상권
# trdar_cd_nm            흑석로9길
# tot_flpop_co         7673090
# ml_flpop_co          4038509
# fml_flpop_co         3634580
# agrde_20_flpop_co    2689987
# agrde_30_flpop_co    1981529
# agrde_40_flpop_co    1578402
# agrde_50_flpop_co    1211469
# dtype: object

# %%
aa[aa['tot_flpop_co'] == 7673090]
# Out:
#     trdar_se_cd_nm trdar_cd_nm  tot_flpop_co  ml_flpop_co  fml_flpop_co  \
# 488           골목상권      북아현로4길       7673090      4038509       3634580
#
#      agrde_20_flpop_co  agrde_30_flpop_co  agrde_40_flpop_co  \
# 488            1801593            1981529            1578402
#
#      agrde_50_flpop_co
# 488            1207046

# %%
aa[aa['ml_flpop_co'] ==4038509 ]
# Out:
#     trdar_se_cd_nm trdar_cd_nm  tot_flpop_co  ml_flpop_co  fml_flpop_co  \
# 488           골목상권      북아현로4길       7673090      4038509       3634580
#
#      agrde_20_flpop_co  agrde_30_flpop_co  agrde_40_flpop_co  \
# 488            1801593            1981529            1578402
#
#      agrde_50_flpop_co
# 488            1207046

# %%
aa[aa['agrde_20_flpop_co'] == 2689987] #마포구
# Out:
#     trdar_se_cd_nm trdar_cd_nm  tot_flpop_co  ml_flpop_co  fml_flpop_co  \
# 508           골목상권      대흥로21길       5303738      2346641       2957101
#
#      agrde_20_flpop_co  agrde_30_flpop_co  agrde_40_flpop_co  \
# 508            2689987             802295             519484
#
#      agrde_50_flpop_co
# 508             507690

# %%
aa[aa['agrde_30_flpop_co'] == 1981529] #서대문구
# Out:
#     trdar_se_cd_nm trdar_cd_nm  tot_flpop_co  ml_flpop_co  fml_flpop_co  \
# 488           골목상권      북아현로4길       7673090      4038509       3634580
#
#      agrde_20_flpop_co  agrde_30_flpop_co  agrde_40_flpop_co  \
# 488            1801593            1981529            1578402
#
#      agrde_50_flpop_co
# 488            1207046

# %%
aa[aa['agrde_40_flpop_co'] == 1578402]
# Out:
#     trdar_se_cd_nm trdar_cd_nm  tot_flpop_co  ml_flpop_co  fml_flpop_co  \
# 488           골목상권      북아현로4길       7673090      4038509       3634580
#
#      agrde_20_flpop_co  agrde_30_flpop_co  agrde_40_flpop_co  \
# 488            1801593            1981529            1578402
#
#      agrde_50_flpop_co
# 488            1207046

# %%
aa[aa['agrde_50_flpop_co'] == 1211469]
# Out:
#     trdar_se_cd_nm trdar_cd_nm  tot_flpop_co  ml_flpop_co  fml_flpop_co  \
# 493           골목상권      신촌로37길       7591396      3958952       3632443
#
#      agrde_20_flpop_co  agrde_30_flpop_co  agrde_40_flpop_co  \
# 493            1768195            1951495            1555277
#
#      agrde_50_flpop_co
# 493            1211469
